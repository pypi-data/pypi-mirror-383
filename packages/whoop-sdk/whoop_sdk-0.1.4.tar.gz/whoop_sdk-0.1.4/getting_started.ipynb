# %%
from whoop_sdk import Whoop
whoop = Whoop()

# %%
whoop.login()
# Out:
# ✅ You're already logged in!
# If you need to re-authenticate, call auth.reset_config() first.
# True

# %%
whoop.get_profile()
# Out:
# {'user_id': 31453705,
#  'email': 'ejflynn27@gmail.com',
#  'first_name': 'Eric',
#  'last_name': 'Flynn'}

# %%
whoop.get_sleep()
# Out:
# {'records': [{'id': '37213d3e-6e53-4b65-a5de-5bee28ba2461',
#    'cycle_id': 1102746757,
#    'v1_id': -2137386614,
#    'user_id': 31453705,
#    'created_at': '2025-10-11T13:23:30.040Z',
#    'updated_at': '2025-10-11T13:23:30.040Z',
#    'start': '2025-10-11T04:22:30.850Z',
#    'end': '2025-10-11T13:21:54.860Z',
#    'timezone_offset': '-04:00',
#    'nap': False,
#    'score_state': 'SCORED',
#    'score': {'stage_summary': {'total_in_bed_time_milli': 31957370,
#      'total_awake_time_milli': 2491060,
#      'total_no_data_time_milli': 0,
#      'total_light_sleep_time_milli': 16531660,
#      'total_slow_wave_sleep_time_milli': 5642230,
#      'total_rem_sleep_time_milli': 7292420,
#      'sleep_cycle_count': 4,
#      'disturbance_count': 13},
#     'sleep_needed': {'baseline_milli': 27725652,
#      'need_from_sleep_debt_milli': 2423007,
#      'need_from_recent_strain_milli': 313398,
#      'need_from_recent_nap_milli': 0},
#     'respiratory_rate': 14.003906,
# ...

# %%
whoop.get_recovery()
# Out:
# {'records': [{'cycle_id': 1102746757,
#    'sleep_id': '37213d3e-6e53-4b65-a5de-5bee28ba2461',
#    'user_id': 31453705,
#    'created_at': '2025-10-11T13:23:30.040Z',
#    'updated_at': '2025-10-11T13:23:30.040Z',
#    'score_state': 'SCORED',
#    'score': {'user_calibrating': False,
#     'recovery_score': 37.0,
#     'resting_heart_rate': 63.0,
#     'hrv_rmssd_milli': 80.882545,
#     'spo2_percentage': 96.28571,
#     'skin_temp_celsius': 32.828335}},
#   {'cycle_id': 1100984808,
#    'sleep_id': '480716a6-73cb-4f5d-b401-f2b4e4050c79',
#    'user_id': 31453705,
#    'created_at': '2025-10-10T10:38:27.881Z',
#    'updated_at': '2025-10-10T10:38:27.881Z',
#    'score_state': 'SCORED',
#    'score': {'user_calibrating': False,
#     'recovery_score': 55.0,
#     'resting_heart_rate': 57.0,
#     'hrv_rmssd_milli': 104.48222,
#     'spo2_percentage': 95.03846,
#     'skin_temp_celsius': 32.09}},
#   {'cycle_id': 1099466896,
#    'sleep_id': 'a21f896d-0452-4c59-8c71-10a6b34806c7',
# ...

# %%
whoop.get_workout()
# Out:
# {'records': [{'id': 'f74b2bad-9396-4d44-903a-4cbe028db1e8',
#    'v1_id': -2138742624,
#    'user_id': 31453705,
#    'created_at': '2025-10-11T03:34:04.280Z',
#    'updated_at': '2025-10-11T03:34:29.999Z',
#    'start': '2025-10-11T03:15:00.000Z',
#    'end': '2025-10-11T03:33:00.000Z',
#    'timezone_offset': '-04:00',
#    'sport_name': 'stretching',
#    'score_state': 'SCORED',
#    'score': None,
#    'sport_id': 128},
#   {'id': 'bf3b0869-628c-4fc7-8dde-f867b68623c2',
#    'v1_id': -2141828075,
#    'user_id': 31453705,
#    'created_at': '2025-10-09T20:43:34.157Z',
#    'updated_at': '2025-10-09T20:43:52.653Z',
#    'start': '2025-10-09T20:22:19.892Z',
#    'end': '2025-10-09T20:43:33.420Z',
#    'timezone_offset': '-04:00',
#    'sport_name': 'pickleball',
#    'score_state': 'SCORED',
#    'score': {'strain': 8.10536,
#     'average_heart_rate': 136,
#     'max_heart_rate': 165,
#     'kilojoule': 877.0993,
#     'percent_recorded': 1.0,
#     'distance_meter': None,
# ...
